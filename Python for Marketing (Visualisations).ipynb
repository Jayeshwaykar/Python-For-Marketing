# %% [markdown]
# # Customising Visualisations

# %%
# import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings # for managing error message
warnings.filterwarnings('ignore')

# %%
# importing and exporting data
ga_gsc_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\gsc_data\ga_gsc_data.csv')

# %%
ga_gsc_data.head()
# Out:
#    Unnamed: 0                                               Page  Clicks  \
# 0           0                            https://miratrix.co.uk/     371
# 1           1       https://miratrix.co.uk/app-marketing-agency/      80
# 2           2  https://miratrix.co.uk/mobile-app-competitor-a...      16
# 3           3  https://miratrix.co.uk/blippar-the-message-isn...      11
# 4           4              https://miratrix.co.uk/author/nduddy/      10
#
#    Impressions    CTR  Position          Avg. Time on Page  Bounce Rate  \
# 0       100673  0.37%     42.59  0 days 00:01:43.666666666    47.296667
# 1        30824  0.26%     26.84  0 days 00:01:45.333333333    64.436667
# 2         1458   1.1%     30.64            0 days 00:04:06    53.335000
# 3          517  2.13%     36.05  0 days 00:00:22.333333333    58.170000
# 4          140  7.14%      5.61            0 days 00:02:52    22.223333
#
#         Exit  ('Pageviews', 'sum')  Unique Pageviews
# 0  54.286667                  1396              1095
# 1  60.913333                   210               181
# 2  89.475000                    30                26
# 3  78.333333                    27                21
# 4  38.890000                    15                13

# %%
ga_gsc_data[ [ "Page", "Clicks", "Impressions","CTR","Position","Avg. Time on Page","Bounce Rate","Exit","('Pageviews', 'sum')","Unique Pageviews"] ]
# Out:
#                                                   Page  Clicks  Impressions  \
# 0                              https://miratrix.co.uk/     371       100673
# 1         https://miratrix.co.uk/app-marketing-agency/      80        30824
# 2    https://miratrix.co.uk/mobile-app-competitor-a...      16         1458
# 3    https://miratrix.co.uk/blippar-the-message-isn...      11          517
# 4                https://miratrix.co.uk/author/nduddy/      10          140
# ..                                                 ...     ...          ...
# 188         https://miratrix.co.uk/tag/twitter-emojis/       0            2
# 189       https://miratrix.co.uk/tag/estate-agent-app/       0            2
# 190  https://miratrix.co.uk/making-a-difference/bei...       0            1
# 191  https://miratrix.co.uk/organic-app-growth/our-...       0            1
# 192      https://miratrix.co.uk/author/nduddy/page/21/       0            1
#
#        CTR  Position          Avg. Time on Page  Bounce Rate        Exit  \
# 0    0.37%     42.59  0 days 00:01:43.666666666    47.296667   54.286667
# 1    0.26%     26.84  0 days 00:01:45.333333333    64.436667   60.913333
# 2     1.1%     30.64            0 days 00:04:06    53.335000   89.475000
# 3    2.13%     36.05  0 days 00:00:22.333333333    58.170000   78.333333
# 4    7.14%      5.61            0 days 00:02:52    22.223333   38.890000
# ..     ...       ...                        ...          ...         ...
# 188     0%     51.00            0 days 00:00:00   100.000000  100.000000
# 189     0%     74.00            0 days 00:00:00   100.000000  100.000000
# 190     0%      1.00     0 days 00:04:32.500000    71.430000   93.750000
# 191     0%      4.00            0 days 00:03:47     0.000000    0.000000
# 192     0%      5.00            0 days 00:00:10     0.000000    0.000000
#
#      ('Pageviews', 'sum')  Unique Pageviews
# 0                    1396              1095
# 1                     210               181
# 2                      30                26
# 3                      27                21
# 4                      15                13
# ..                    ...               ...
# 188                     1                 1
# 189                     1                 1
# 190                     9                 8
# 191                     2                 1
# 192                     1                 1
#
# [193 rows x 10 columns]

# %%
# view the make up of the data using .info()
ga_gsc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            193 non-null    int64
#  1   Page                  193 non-null    object
#  2   Clicks                193 non-null    int64
#  3   Impressions           193 non-null    int64
#  4   CTR                   193 non-null    object
#  5   Position              193 non-null    float64
#  6   Avg. Time on Page     193 non-null    object
#  7   Bounce Rate           193 non-null    float64
#  8   Exit                  193 non-null    float64
#  9   ('Pageviews', 'sum')  193 non-null    int64
#  10  Unique Pageviews      193 non-null    int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 16.7+ KB

# %%
ga_gsc_data = ga_gsc_data.drop("Unnamed: 0",axis ='columns')

# %%
ga_gsc_data.head()
# Out:
#                                                 Page  Clicks  Impressions  \
# 0                            https://miratrix.co.uk/     371       100673
# 1       https://miratrix.co.uk/app-marketing-agency/      80        30824
# 2  https://miratrix.co.uk/mobile-app-competitor-a...      16         1458
# 3  https://miratrix.co.uk/blippar-the-message-isn...      11          517
# 4              https://miratrix.co.uk/author/nduddy/      10          140
#
#      CTR  Position          Avg. Time on Page  Bounce Rate       Exit  \
# 0  0.37%     42.59  0 days 00:01:43.666666666    47.296667  54.286667
# 1  0.26%     26.84  0 days 00:01:45.333333333    64.436667  60.913333
# 2   1.1%     30.64            0 days 00:04:06    53.335000  89.475000
# 3  2.13%     36.05  0 days 00:00:22.333333333    58.170000  78.333333
# 4  7.14%      5.61            0 days 00:02:52    22.223333  38.890000
#
#    ('Pageviews', 'sum')  Unique Pageviews
# 0                  1396              1095
# 1                   210               181
# 2                    30                26
# 3                    27                21
# 4                    15                13

# %%
ga_gsc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Page                  193 non-null    object
#  1   Clicks                193 non-null    int64
#  2   Impressions           193 non-null    int64
#  3   CTR                   193 non-null    object
#  4   Position              193 non-null    float64
#  5   Avg. Time on Page     193 non-null    object
#  6   Bounce Rate           193 non-null    float64
#  7   Exit                  193 non-null    float64
#  8   ('Pageviews', 'sum')  193 non-null    int64
#  9   Unique Pageviews      193 non-null    int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 15.2+ KB

# %%
ga_gsc_data.set_index('Page',inplace = True)

# %% [markdown]
# ## Prepare Data for Visualisation

# %%
ga_gsc_data.CTR = ga_gsc_data.CTR.str.replace('%','')

# %%
ga_gsc_data['Avg. Time on Page'] = ga_gsc_data['Avg. Time on Page'].str.replace('0 days','').apply(pd.Timedelta)

# %%
# Set Page as Index
ga_gsc_data.head()
# Out:
#                                                     Clicks  Impressions   CTR  \
# Page
# https://miratrix.co.uk/                                371       100673  0.37
# https://miratrix.co.uk/app-marketing-agency/            80        30824  0.26
# https://miratrix.co.uk/mobile-app-competitor-an...      16         1458   1.1
# https://miratrix.co.uk/blippar-the-message-isnt...      11          517  2.13
# https://miratrix.co.uk/author/nduddy/                   10          140  7.14
#
#                                                     Position  \
# Page
# https://miratrix.co.uk/                                42.59
# https://miratrix.co.uk/app-marketing-agency/           26.84
# https://miratrix.co.uk/mobile-app-competitor-an...     30.64
# https://miratrix.co.uk/blippar-the-message-isnt...     36.05
# https://miratrix.co.uk/author/nduddy/                   5.61
#
#                                                            Avg. Time on Page  \
# Page
# https://miratrix.co.uk/                            0 days 00:01:43.666666666
# https://miratrix.co.uk/app-marketing-agency/       0 days 00:01:45.333333333
# https://miratrix.co.uk/mobile-app-competitor-an...           0 days 00:04:06
# https://miratrix.co.uk/blippar-the-message-isnt... 0 days 00:00:22.333333333
# https://miratrix.co.uk/author/nduddy/                        0 days 00:02:52
#
#                                                     Bounce Rate       Exit  \
# Page
# https://miratrix.co.uk/                               47.296667  54.286667
# https://miratrix.co.uk/app-marketing-agency/          64.436667  60.913333
# https://miratrix.co.uk/mobile-app-competitor-an...    53.335000  89.475000
# https://miratrix.co.uk/blippar-the-message-isnt...    58.170000  78.333333
# https://miratrix.co.uk/author/nduddy/                 22.223333  38.890000
#
#                                                     ('Pageviews', 'sum')  \
# Page
# https://miratrix.co.uk/                                             1396
# https://miratrix.co.uk/app-marketing-agency/                         210
# https://miratrix.co.uk/mobile-app-competitor-an...                    30
# https://miratrix.co.uk/blippar-the-message-isnt...                    27
# https://miratrix.co.uk/author/nduddy/                                 15
#
#                                                     Unique Pageviews
# Page
# https://miratrix.co.uk/                                         1095
# https://miratrix.co.uk/app-marketing-agency/                     181
# https://miratrix.co.uk/mobile-app-competitor-an...                26
# https://miratrix.co.uk/blippar-the-message-isnt...                21
# https://miratrix.co.uk/author/nduddy/                             13

# %%
ga_gsc_data = ga_gsc_data.rename(columns={"('Pageviews', 'sum')": "Pageviews"})

# %% [markdown]
# ## Plot a basic visualisations

# %%
# Plot a basic bar chart showing the statical breakdown the data set
ga_gsc_data.describe().plot.bar(figsize=(15,5),secondary_y='Impressions')
# Out:
# <AxesSubplot:>

# %%
ga_gsc_data[['Clicks','Pageviews','Position']][:20].plot.bar(figsize=(15,5),
                                                            secondary_y=('Position'))
# Out:
# <AxesSubplot:xlabel='Page'>

# %% [markdown]
# ## Customising Plots with matplotlib

# %% [markdown]
# ## creating matplotlib subplots

# %%
# create subplots of two series of data from ga_gac_data
fig = plt.figure(figsize=(15,5)) # Create matplotlib figure

ax = fig.add_subplot(121) # create matplotlib axes (nrows,ncolumns, position)
ax2 = fig.add_subplot(122) # create another axes

# first plot
ga_gsc_data['Clicks'][:10].plot.bar(ax=ax)

# second plot
ga_gsc_data['Pageviews'][:10].plot.bar(ax=ax2)

plt.show()

# %% [markdown]
# ## Plotting two Y-axis

# %%
fig = plt.figure(figsize = (15,5))

ax = fig.add_subplot(111)

ax2 = ax.twinx()

width = 0.2

ga_gsc_data['Clicks'][:10].plot.bar(color='red',
                                   ax=ax,
                                   width = width,
                                   position =1)
ga_gsc_data['Pageviews'][:10].plot(kind = 'bar',
                                   color='blue',
                                   ax=ax2,
                                   width = width,
                                   position =0)

plt.show()

# %% [markdown]
# ## Adding x and y labels to a plot

# %%
fig = plt.figure(figsize = (15,5))

ax = fig.add_subplot(111)

ax2 = ax.twinx()

width = 0.2

ga_gsc_data['Clicks'][:10].plot(kind = 'bar',
                                color='yellow',
                                ax=ax,
                                width = width,
                                position =1,
                                fontsize = 10)
ga_gsc_data['Pageviews'][:10].plot(kind = 'bar',
                                   color='lightgreen',
                                   ax=ax2,
                                   width = width,
                                   position =0)

plt.show()

# %% [markdown]
# ## Rotating xticks labels on plot

# %%
fig = plt.figure(figsize=(15,5))

ax= fig.add_subplot(111)
ax2 = ax.twinx()

width = 0.2

ga_gsc_data ['Clicks'][:10].plot(kind='bar',
                                  color='yellow',
                                  ax=ax,
                                  width = width,
                                  position =1,
                                  fontsize = 10)

ga_gsc_data ['Pageviews'][:10].plot(kind='bar',
                                  color='lightgreen',
                                  ax=ax2,
                                  width = width,
                                  position =0)

# Create ax customatisations
ax.set_xlabel('Page')
ax.set_ylabel('Clicks')
ax.set_xticklabels(ax.get_xticklabels(),
                  rotation = -45 )

# Create ax2 customatisations
ax2.set_ylabel('Pageviews')

plt.show()

# %% [markdown]
# ## Adding a legend to a plot

# %%
fig = plt.figure(figsize=(15,5))

ax = fig.add_subplot(111) # create matplotlib axes
ax2 = ax.twinx()

width = 0.2

ga_gsc_data['Clicks'][:10].plot(kind = 'bar',
                               color = 'yellow',
                               ax= ax,
                               width = width,
                               position = 1,
                               fontsize = 10)
ga_gsc_data['Pageviews'][:10].plot(kind = 'bar',
                                  color = 'lightgreen',
                                  ax=ax2,
                                  width = width,
                                  position = 0)


# Create ax customatisations
ax.set_xlabel('Page')
ax.set_ylabel('Clicks')
ax.set_xticklabels(ax.get_xticklabels(),
                  rotation = -45 )

# Create ax2 customatisations
ax2.set_ylabel('Pageviews')

fig.legend()

plt.show()

# %% [markdown]
# ## Adding a title to your plot

# %%
fig = plt.figure(figsize=(15,5))

ax = fig.add_subplot(111) # create matplotlib axes
ax2 = ax.twinx()

width = 0.2

ga_gsc_data['Clicks'][:10].plot(kind = 'bar',
                               color = 'yellow',
                               ax= ax,
                               width = width,
                               position = 1,
                               fontsize = 10)

ga_gsc_data['Pageviews'][:10].plot(kind = 'bar',
                                  color = 'lightgreen',
                                  ax=ax2,
                                  width = width,
                                  position = 0)


# Create ax customatisations
ax.set_xlabel('Page')
ax.set_ylabel('Clicks')
ax.set_xticklabels(ax.get_xticklabels(),
                  rotation = -45 )

# Create ax2 customatisations
ax2.set_ylabel('Pageviews')

plt.title('Bar Chart : Clicks vs Pagevies')

fig.legend()

plt.show()

# %% [markdown]
# ## Adding annotation to a plot

# %%
fig = plt.figure(figsize=(15,5)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.2 #set the width of the bars

ga_gsc_data['Clicks'][:10].plot(kind='bar', #type of chart to use
                                color='yellow', #colour of bar
                                ax=ax, #what matplotlinb axes to use
                                width=width, #set the bar width
                                position=1, #the postion of the bar relative to the others
                                fontsize=10) #set font size 
ga_gsc_data['Pageviews'][:10].plot(kind='bar', 
                                   color='lightgreen', 
                                   ax=ax2,
                                   width=width,
                                   position=0)

#Create ax customatisations
ax.annotate('Lots of Pageviews but few clicks', 
            xy=(8, 50), 
            xytext=(2, 120),
            arrowprops=dict(facecolor='cyan', #colour
                            shrink=0.05, #length of arrow
                            lw=1, #line width
                            ec='magenta', #boarder colour
                            zorder=1) #layering order of annotation
           )
ax.set_xlabel('Page') #name the x axis
ax.set_ylabel('Clicks') # name the primary y axis
ax.set_xticklabels(ax.get_xticklabels(), #get a strings with the label names
                   rotation=45) #Rotate the xticks labels by degrees

#Create ax customatisations
ax2.annotate('Lots of Pageviews and clicks', 
            xy=(0, 1398), 
            xytext=(1, 1398),
            arrowprops=dict(facecolor='cyan', #colour
                            shrink=0.05, #length of arrow
                            lw=1, #line width
                            ec='magenta', #boarder colour
                            zorder=1) #layering order of annotation
           )
ax2.set_ylabel('Pageviews') #name the secondary y axis

#Global Plot settings
plt.title('Bar Chart: Clicks vs Pageview') # set chart name
fig.legend() # set the legend

#display the charts
plt.show()

# %% [markdown]
# ## Switching between Matplotlib styles sheets

# %%
plt.style.use('seaborn-pastel')

fig = plt.figure(figsize=(15,5)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.2 #set the width of the bars

ga_gsc_data['Clicks'][:10].plot(kind='bar', #type of chart to use
                                color='yellow', #colour of bar
                                ax=ax, #what matplotlinb axes to use
                                width=width, #set the bar width
                                position=1, #the postion of the bar relative to the others
                                fontsize=10) #set font size 
ga_gsc_data['Pageviews'][:10].plot(kind='bar', 
                                   color='lightgreen', 
                                   ax=ax2,
                                   width=width,
                                   position=0)

#Create ax customatisations
ax.annotate('Lots of Pageviews but few clicks', 
            xy=(8, 50), 
            xytext=(2, 120),
            arrowprops=dict(facecolor='cyan', #colour
                            shrink=0.05, #length of arrow
                            lw=1, #line width
                            ec='magenta', #boarder colour
                            zorder=1) #layering order of annotation
           )
ax.set_xlabel('Page') #name the x axis
ax.set_ylabel('Clicks') # name the primary y axis
ax.set_xticklabels(ax.get_xticklabels(), #get a strings with the label names
                   rotation=45) #Rotate the xticks labels by degrees

#Create ax customatisations
ax2.annotate('Lots of Pageviews and clicks', 
            xy=(0, 1398), 
            xytext=(1, 1398),
            arrowprops=dict(facecolor='cyan', #colour
                            shrink=0.05, #length of arrow
                            lw=1, #line width
                            ec='magenta', #boarder colour
                            zorder=1) #layering order of annotation
           )
ax2.set_ylabel('Pageviews') #name the secondary y axis

#Global Plot settings
plt.title('Bar Chart: Clicks vs Pageview') # set chart name
fig.legend() # set the legend

#display the charts
plt.show()

# %% [markdown]
# ## Plotting in seaborn

# %% [markdown]
# ## Plot a scatter plot in seaborn

# %%
fig = plt.figure(figsize=(15,5)) # Create matplotlib figure
ax = fig.add_subplot(111) # Create matplotlib axes

sns.scatterplot(x='Impressions', # x axes
                y="Clicks", # y axes
                data=ga_gsc_data) #the dataset we're using

#display the charts
plt.show()

# %%
fig = plt.figure(figsize=(15,5)) # Create matplotlib figure
ax = fig.add_subplot(111) # Create matplotlib axes

sns.scatterplot(x='Impressions', # x axes
                y="Clicks", # y axes
                hue='Position',# colouring the dots based on a num value
                data=ga_gsc_data) #the dataset we're using

#display the charts
plt.show()

# %%
fig = plt.figure(figsize=(15,5)) # Create matplotlib figure
ax = fig.add_subplot(111) # Create matplotlib axes

sns.scatterplot(x='Impressions',# x axes
                y="Clicks",# xy axes
                hue='Position',# colouring the dots based on a num value
                size="Pageviews", # increasing the size of the dots based on a num values
                data=ga_gsc_data) #the dataset we're using

#display the charts
plt.show()

# %%
fig = plt.figure(figsize=(15,5)) # Create matplotlib figure
ax = fig.add_subplot(111) # Create matplotlib axes

sns.scatterplot(x='Impressions',# x axes
                y="Clicks",# xy axes
                hue='Position',# colouring the dots based on a num value
                size="Pageviews", # increasing the size of the dots based on a num values
                palette="Set2", # selecting a colour palette
                data=ga_gsc_data) #the dataset we're using

#display the charts
plt.show()

# %% [markdown]
# ## Plot a Facebook ad metric heatmap in seaborn

# %%
fb_camp_data = pd.read_csv('D:\\Python for Marketing\\Ex_Files_Python_Marketing\\Ex_Files_Python_Marketing\\Exercise Files\\data\\other_data\\fb_example_data.csv')

# %%
fb_camp_data.head()
# Out:
#    Results  Reach  Frequency  Cost per results  Budget  Amount spent (GBP)  \
# 0      105  77905   1.182132          2.871238   187.2              301.48
# 1       77  59035   1.204590          3.910130   187.2              301.08
# 2       49  48718   1.254116          6.135102   187.2              300.62
# 3       66  66413   1.259859          3.957727   187.2              261.21
# 4       47  64472   1.320946          5.499787   187.2              258.49
#
#    Clicks (all)  CTR (all)  CPC (all) (GBP)  Impressions  \
# 0          2570   2.790627         0.117307        92094
# 1          1846   2.595869         0.163099        71113
# 2          1485   2.430521         0.202438        61098
# 3          1703   2.035353         0.153382        83671
# 4          1373   1.612184         0.188267        85164
#
#    CPM (cost per 1,000 impressions) (GBP)  Link clicks  \
# 0                                3.273612         2126
# 1                                4.233825         1580
# 2                                4.920292         1223
# 3                                3.121870         1342
# 4                                3.035203         1099
#
#    CPC (cost per link click) (GBP)  CTR (link click-through rate)  \
# 0                         0.141806                       2.308511
# 1                         0.190557                       2.221816
# 2                         0.245805                       2.001702
# 3                         0.194642                       1.603901
# 4                         0.235205                       1.290451
#
#    Website purchases  Website purchases conversion value  \
# 0                105                            10927.20
# 1                 77                             8525.30
# 2                 49                             5955.55
# 3                 66                             9079.10
# 4                 47                             4602.00
#
#    Website purchase ROAS (return on advertising spend)  Button clicks
# 0                                          36.245190              482
# 1                                          28.315730              319
# 2                                          19.810891              261
# 3                                          34.757858              342
# 4                                          17.803397              257

# %%
fb_camp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 18 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Results                                              19 non-null     int64
#  1   Reach                                                19 non-null     int64
#  2   Frequency                                            19 non-null     float64
#  3   Cost per results                                     19 non-null     float64
#  4   Budget                                               19 non-null     float64
#  5   Amount spent (GBP)                                   19 non-null     float64
#  6   Clicks (all)                                         19 non-null     int64
#  7   CTR (all)                                            19 non-null     float64
#  8   CPC (all) (GBP)                                      19 non-null     float64
#  9   Impressions                                          19 non-null     int64
#  10  CPM (cost per 1,000 impressions) (GBP)               19 non-null     float64
#  11  Link clicks                                          19 non-null     int64
#  12  CPC (cost per link click) (GBP)                      19 non-null     float64
#  13  CTR (link click-through rate)                        19 non-null     float64
#  14  Website purchases                                    19 non-null     int64
#  15  Website purchases conversion value                   19 non-null     float64
#  16  Website purchase ROAS (return on advertising spend)  19 non-null     float64
#  17  Button clicks                                        19 non-null     int64
# dtypes: float64(11), int64(7)
# memory usage: 2.8 KB

# %%
fb_corr = fb_camp_data.corr()

# %%
#Use seaborn to draw a heatmap of the correlated features in our dataset
plt.figure(figsize=(20,16))
sns.heatmap(fb_corr, #load data
           linewidth=0.5, #line width
           cmap='RdBu_r', #prefered colour maps
           vmin=-1, #min range of board
           vmax=1, #max range of board
           annot=True) #add annotation

#display the charts
plt.show()

# %% [markdown]
# ## Working with timeseries

# %%
ga_page_traffic_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_pages.csv',
                                  skiprows =386,
                                  nrows = 366,
                                  usecols=['Day Index','Pageviews'],
                                  parse_dates=['Day Index'],
                                  index_col = 'Day Index')

# %%
ppc_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\other_data\ppc_data.csv',
                      parse_dates =['Day'],
                      index_col = 'Day')

# %% [markdown]
# ## Exploring timeseries data

# %%
ga_page_traffic_data.head()
# Out:
#             Pageviews
# Day Index
# 2018-08-31         14
# 2018-09-01          6
# 2018-09-02         17
# 2018-09-03         14
# 2018-09-04         11

# %%
ga_page_traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2018-08-31 to 2019-08-31
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pageviews  366 non-null    int64
# dtypes: int64(1)
# memory usage: 5.7 KB

# %%
ga_page_traffic_data.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day Index'>

# %% [markdown]
# ## Fixing missing values in the data

# %%
ga_page_traffic_data.describe()
# Out:
#         Pageviews
# count  366.000000
# mean     9.065574
# std     16.412694
# min      0.000000
# 25%      3.000000
# 50%      6.000000
# 75%     12.000000
# max    274.000000

# %%
average_value= ga_page_traffic_data['Pageviews'].mean()

# %%
average_value
# Out:
# 9.065573770491802

# %%
ga_page_traffic_data['Pageviews'].replace(0,
                                         average_value,
                                         inplace=True)

# %%
ga_page_traffic_data.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day Index'>

# %% [markdown]
# ## Resampling Timeseries data

# %% [markdown]
# ## Monthly resampling

# %%
ga_page_monthly = ga_page_traffic_data.resample('M').mean()

# %%
ga_page_monthly.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day Index'>

# %% [markdown]
# ## Quarterly resampling

# %%
ga_page_quarterly = ga_page_traffic_data.resample('Q',convention='end').mean()

# %%
ga_page_quarterly.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day Index'>

# %% [markdown]
# ## Resampling and rolling avg plots

# %% [markdown]
# ## Calculating the CPC Weekly avg

# %%
ppc_data.head()
# Out:
#             Unnamed: 0              Ad group  Avg. CPC        CTR  \
# Day
# 2018-08-31           0  miratrix_ppc_adgroup  2.490563  16.894144
# 2018-09-01           1  miratrix_ppc_adgroup  2.472161   5.976134
# 2018-09-02           2  miratrix_ppc_adgroup  2.508561   6.824919
# 2018-09-03           3  miratrix_ppc_adgroup  2.548919   8.058366
# 2018-09-04           4  miratrix_ppc_adgroup  2.414868   6.884937
#
#                 Campaign  Clicks  Conv. rate  Conversions         Cost  \
# Day
# 2018-08-31  miratrix_ppc      75    0.225225            1  1105.809783
# 2018-09-01  miratrix_ppc      17    1.193317            5  1035.835572
# 2018-09-02  miratrix_ppc       3    0.107411            1  2335.470042
# 2018-09-03  miratrix_ppc      99    2.723735            7   655.072102
# 2018-09-04  miratrix_ppc      93    1.464435            7  1154.306794
#
#             Cost / conv. Final URL  Impr.  Keyword Keyword status  Max. CPC  \
# Day
# 2018-08-31   1105.809783      Text   7501  keyword         Active       2.6
# 2018-09-01    207.167114      Text   2504  keyword         Active       2.6
# 2018-09-02   2335.470042      Text   6354  keyword         Active       2.6
# 2018-09-03     93.581729      Text   2071  keyword         Active       2.6
# 2018-09-04    164.900971      Text   3291  keyword         Active       2.6
#
#            Mobile final URL  Status
# Day
# 2018-08-31             Text  Active
# 2018-09-01             Text  Active
# 2018-09-02             Text  Active
# 2018-09-03             Text  Active
# 2018-09-04             Text  Active

# %%
ppc_data['Cost'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day'>

# %% [markdown]
# ## Weekly research

# %%
ppc_weekly = ppc_data['Cost'].resample('W').mean()

# %%
ppc_weekly.head()
# Out:
# Day
# 2018-09-02    1492.371799
# 2018-09-09    1073.762622
# 2018-09-16    1554.423832
# 2018-09-23    1322.445411
# 2018-09-30    1041.005947
# Freq: W-SUN, Name: Cost, dtype: float64

# %%
ppc_weekly.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day'>

# %% [markdown]
# ## Rolling Avg

# %%
ppc_rolling_7d = ppc_data['Cost'].rolling(window=7,
                                         center= True,
                                         ).mean()

# %%
ppc_rolling_7d.head(10)
# Out:
# Day
# 2018-08-31            NaN
# 2018-09-01            NaN
# 2018-09-02            NaN
# 2018-09-03    1248.123595
# 2018-09-04    1319.591703
# 2018-09-05    1310.633560
# 2018-09-06    1073.762622
# 2018-09-07    1320.345163
# 2018-09-08    1317.992852
# 2018-09-09    1089.016399
# Name: Cost, dtype: float64

# %%
ppc_rolling_7d.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Day'>

# %% [markdown]
# ## Plot weekly PPC CPC Comparison

# %%
fig = plt.figure(figsize=(15,5))

ax= fig.add_subplot(111)

figsize = (15,8)

ppc_data['Cost'].plot(figsize=figsize,
                      alpha =.5,
                      marker='.',
                      linestyle = '-',
                      label='Daily')

ppc_weekly.plot(figsize=figsize,
                     marker='x',
                     markersize = 8,
                     linestyle = '-',
                     label='Weekly Mean Resample')

ppc_rolling_7d.plot(figsize=figsize,
                     marker='o',
                     linestyle = '-',
                     label='7-d Rolling Mean')

ax.set_xlabel('Date')
ax.set_ylabel('Cost Per Click (CPC)')

plt.title('COMPARE : Daily, Weekly Mean, 7-d Rolling Mean')

fig.legend()
plt.show()

# %% [markdown]
# ## Adding Dynamic  Annotations

# %%
fig = plt.figure(figsize=(15,5))

ax = fig.add_subplot(111)

figsize = (15,8)

ppc_data['Cost'].plot(figsize=figsize, 
                      alpha=.5, 
                      marker='.', 
                      linestyle='-', 
                      linewidth=0.5, 
                      label='Daily'
                     )

ppc_weekly.plot(figsize=figsize,
                marker='x',
                markersize=8, 
                linestyle='-',
                label='Weekly Mean Resample'
               )

ppc_rolling_7d.plot(figsize=figsize,
                   marker='o',
                   linestyle='-',
                   label='7-d Rolling Mean'
                  )

max_value = ppc_rolling_7d.max()
max_value_index = ppc_rolling_7d.idxmax()

min_value = ppc_rolling_7d.min()
min_value_index = ppc_rolling_7d.idxmin()



#Create dynamic annotations for max values
ax.annotate('Highest CPC: £{}'.format(max_value),
            xy=(max_value_index,max_value),
            xytext=(max_value_index,max_value),
            arrowprops=dict(facecolor='cyan', #colour
                            shrink=0.05, #length of arrow
                            lw=1, #line width
                            ec='magenta', #boarder colour
                            zorder=1)) #layering order of annotation

#Create dynamic annotations for min values
ax.annotate('Lowest CPC: £{}'.format(min_value),
            xy=(min_value_index,min_value),
            xytext=(min_value_index,min_value),
            arrowprops=dict(facecolor='cyan', #colour
                            shrink=0.0, #length of arrow
                            lw=1, #line width
                            ec='magenta', #boarder colour
                            zorder=1)) #layering order of annotation


#Global Plot settings
plt.title('COMPARE: Daily, Weekly Mean, 7-d Rolling Mean ') # set chart name
fig.legend() # set the legend

#display the charts
plt.show()

# %% [markdown]
# ## Calculating and creating new metrics

# %%
ga_gsc_data.head()
# Out:
#                                                     Clicks  Impressions   CTR  \
# Page
# https://miratrix.co.uk/                                371       100673  0.37
# https://miratrix.co.uk/app-marketing-agency/            80        30824  0.26
# https://miratrix.co.uk/mobile-app-competitor-an...      16         1458  1.10
# https://miratrix.co.uk/blippar-the-message-isnt...      11          517  2.13
# https://miratrix.co.uk/author/nduddy/                   10          140  7.14
#
#                                                     Position  CTR true visits  \
# Page
# https://miratrix.co.uk/                                42.59             0.17
# https://miratrix.co.uk/app-marketing-agency/           26.84             0.10
# https://miratrix.co.uk/mobile-app-competitor-an...     30.64             0.07
# https://miratrix.co.uk/blippar-the-message-isnt...     36.05             0.39
# https://miratrix.co.uk/author/nduddy/                   5.61             4.29
#
#                                                            Avg. Time on Page  \
# Page
# https://miratrix.co.uk/                            0 days 00:01:43.666666666
# https://miratrix.co.uk/app-marketing-agency/       0 days 00:01:45.333333333
# https://miratrix.co.uk/mobile-app-competitor-an...           0 days 00:04:06
# https://miratrix.co.uk/blippar-the-message-isnt... 0 days 00:00:22.333333333
# https://miratrix.co.uk/author/nduddy/                        0 days 00:02:52
#
#                                                     Bounce Rate       Exit  \
# Page
# https://miratrix.co.uk/                               47.296667  54.286667
# https://miratrix.co.uk/app-marketing-agency/          64.436667  60.913333
# https://miratrix.co.uk/mobile-app-competitor-an...    53.335000  89.475000
# https://miratrix.co.uk/blippar-the-message-isnt...    58.170000  78.333333
# https://miratrix.co.uk/author/nduddy/                 22.223333  38.890000
#
#                                                     Pageviews  \
# Page
# https://miratrix.co.uk/                                  1396
# https://miratrix.co.uk/app-marketing-agency/              210
# https://miratrix.co.uk/mobile-app-competitor-an...         30
# https://miratrix.co.uk/blippar-the-message-isnt...         27
# https://miratrix.co.uk/author/nduddy/                      15
#
#                                                     Unique Pageviews  \
# Page
# https://miratrix.co.uk/                                         1095
# https://miratrix.co.uk/app-marketing-agency/                     181
# https://miratrix.co.uk/mobile-app-competitor-an...                26
# https://miratrix.co.uk/blippar-the-message-isnt...                21
# https://miratrix.co.uk/author/nduddy/                             13
#
#                                                     num_bounces
# Page
# https://miratrix.co.uk/                                     169
# https://miratrix.co.uk/app-marketing-agency/                 31
# https://miratrix.co.uk/mobile-app-competitor-an...            1
# https://miratrix.co.uk/blippar-the-message-isnt...            2
# https://miratrix.co.uk/author/nduddy/                         6

# %%
ga_gsc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193 entries, https://miratrix.co.uk/ to https://miratrix.co.uk/author/nduddy/page/21/
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Clicks             193 non-null    int64
#  1   Impressions        193 non-null    int64
#  2   CTR                193 non-null    float64
#  3   Position           193 non-null    float64
#  4   CTR true visits    193 non-null    float64
#  5   Avg. Time on Page  193 non-null    timedelta64[ns]
#  6   Bounce Rate        193 non-null    float64
#  7   Exit               193 non-null    float64
#  8   Pageviews          193 non-null    int64
#  9   Unique Pageviews   193 non-null    int64
#  10  num_bounces        193 non-null    int32
# dtypes: float64(5), int32(1), int64(4), timedelta64[ns](1)
# memory usage: 21.4+ KB

# %% [markdown]
# ## Calculating metrics in python

# %%
#Calculating CTR and replace the CTR column
ga_gsc_data.CTR = (ga_gsc_data.Clicks.div(ga_gsc_data.Impressions)*100).round(2)

# %%
ga_gsc_data.CTR.head()
# Out:
# Page
# https://miratrix.co.uk/                                   0.37
# https://miratrix.co.uk/app-marketing-agency/              0.26
# https://miratrix.co.uk/mobile-app-competitor-analysis/    1.10
# https://miratrix.co.uk/blippar-the-message-isnt-clear/    2.13
# https://miratrix.co.uk/author/nduddy/                     7.14
# Name: CTR, dtype: float64

# %%
#Calculate the number of bounces
ga_gsc_data['num_bounces'] = (ga_gsc_data['Clicks'] - (ga_gsc_data.Exit.div(100).multiply(
    ga_gsc_data['Clicks']))).astype(int)

# %%
ga_gsc_data['num_bounces'].head()
# Out:
# Page
# https://miratrix.co.uk/                                   169
# https://miratrix.co.uk/app-marketing-agency/               31
# https://miratrix.co.uk/mobile-app-competitor-analysis/      1
# https://miratrix.co.uk/blippar-the-message-isnt-clear/      2
# https://miratrix.co.uk/author/nduddy/                       6
# Name: num_bounces, dtype: int32

# %%
ga_gsc_data.head()
# Out:
#                                                     Clicks  Impressions   CTR  \
# Page
# https://miratrix.co.uk/                                371       100673  0.37
# https://miratrix.co.uk/app-marketing-agency/            80        30824  0.26
# https://miratrix.co.uk/mobile-app-competitor-an...      16         1458  1.10
# https://miratrix.co.uk/blippar-the-message-isnt...      11          517  2.13
# https://miratrix.co.uk/author/nduddy/                   10          140  7.14
#
#                                                     Position  CTR true visits  \
# Page
# https://miratrix.co.uk/                                42.59             0.17
# https://miratrix.co.uk/app-marketing-agency/           26.84             0.10
# https://miratrix.co.uk/mobile-app-competitor-an...     30.64             0.07
# https://miratrix.co.uk/blippar-the-message-isnt...     36.05             0.39
# https://miratrix.co.uk/author/nduddy/                   5.61             4.29
#
#                                                            Avg. Time on Page  \
# Page
# https://miratrix.co.uk/                            0 days 00:01:43.666666666
# https://miratrix.co.uk/app-marketing-agency/       0 days 00:01:45.333333333
# https://miratrix.co.uk/mobile-app-competitor-an...           0 days 00:04:06
# https://miratrix.co.uk/blippar-the-message-isnt... 0 days 00:00:22.333333333
# https://miratrix.co.uk/author/nduddy/                        0 days 00:02:52
#
#                                                     Bounce Rate       Exit  \
# Page
# https://miratrix.co.uk/                               47.296667  54.286667
# https://miratrix.co.uk/app-marketing-agency/          64.436667  60.913333
# https://miratrix.co.uk/mobile-app-competitor-an...    53.335000  89.475000
# https://miratrix.co.uk/blippar-the-message-isnt...    58.170000  78.333333
# https://miratrix.co.uk/author/nduddy/                 22.223333  38.890000
#
#                                                     Pageviews  \
# Page
# https://miratrix.co.uk/                                  1396
# https://miratrix.co.uk/app-marketing-agency/              210
# https://miratrix.co.uk/mobile-app-competitor-an...         30
# https://miratrix.co.uk/blippar-the-message-isnt...         27
# https://miratrix.co.uk/author/nduddy/                      15
#
#                                                     Unique Pageviews  \
# Page
# https://miratrix.co.uk/                                         1095
# https://miratrix.co.uk/app-marketing-agency/                     181
# https://miratrix.co.uk/mobile-app-competitor-an...                26
# https://miratrix.co.uk/blippar-the-message-isnt...                21
# https://miratrix.co.uk/author/nduddy/                             13
#
#                                                     num_bounces
# Page
# https://miratrix.co.uk/                                     169
# https://miratrix.co.uk/app-marketing-agency/                 31
# https://miratrix.co.uk/mobile-app-competitor-an...            1
# https://miratrix.co.uk/blippar-the-message-isnt...            2
# https://miratrix.co.uk/author/nduddy/                         6

# %%
ga_gsc_data.head()
# Out:
#                                                     Clicks  Impressions   CTR  \
# Page
# https://miratrix.co.uk/                                371       100673  0.37
# https://miratrix.co.uk/app-marketing-agency/            80        30824  0.26
# https://miratrix.co.uk/mobile-app-competitor-an...      16         1458  1.10
# https://miratrix.co.uk/blippar-the-message-isnt...      11          517  2.13
# https://miratrix.co.uk/author/nduddy/                   10          140  7.14
#
#                                                     Position  CTR true visits  \
# Page
# https://miratrix.co.uk/                                42.59             0.17
# https://miratrix.co.uk/app-marketing-agency/           26.84             0.10
# https://miratrix.co.uk/mobile-app-competitor-an...     30.64             0.07
# https://miratrix.co.uk/blippar-the-message-isnt...     36.05             0.39
# https://miratrix.co.uk/author/nduddy/                   5.61             4.29
#
#                                                            Avg. Time on Page  \
# Page
# https://miratrix.co.uk/                            0 days 00:01:43.666666666
# https://miratrix.co.uk/app-marketing-agency/       0 days 00:01:45.333333333
# https://miratrix.co.uk/mobile-app-competitor-an...           0 days 00:04:06
# https://miratrix.co.uk/blippar-the-message-isnt... 0 days 00:00:22.333333333
# https://miratrix.co.uk/author/nduddy/                        0 days 00:02:52
#
#                                                     Bounce Rate       Exit  \
# Page
# https://miratrix.co.uk/                               47.296667  54.286667
# https://miratrix.co.uk/app-marketing-agency/          64.436667  60.913333
# https://miratrix.co.uk/mobile-app-competitor-an...    53.335000  89.475000
# https://miratrix.co.uk/blippar-the-message-isnt...    58.170000  78.333333
# https://miratrix.co.uk/author/nduddy/                 22.223333  38.890000
#
#                                                     Pageviews  \
# Page
# https://miratrix.co.uk/                                  1396
# https://miratrix.co.uk/app-marketing-agency/              210
# https://miratrix.co.uk/mobile-app-competitor-an...         30
# https://miratrix.co.uk/blippar-the-message-isnt...         27
# https://miratrix.co.uk/author/nduddy/                      15
#
#                                                     Unique Pageviews  \
# Page
# https://miratrix.co.uk/                                         1095
# https://miratrix.co.uk/app-marketing-agency/                     181
# https://miratrix.co.uk/mobile-app-competitor-an...                26
# https://miratrix.co.uk/blippar-the-message-isnt...                21
# https://miratrix.co.uk/author/nduddy/                             13
#
#                                                     num_bounces
# Page
# https://miratrix.co.uk/                                     169
# https://miratrix.co.uk/app-marketing-agency/                 31
# https://miratrix.co.uk/mobile-app-competitor-an...            1
# https://miratrix.co.uk/blippar-the-message-isnt...            2
# https://miratrix.co.uk/author/nduddy/                         6

# %% [markdown]
# ## Filter

# %%
#Filter the data by pages that have recieved 100 or more clicks
ga_gsc_data[ga_gsc_data['Clicks'] >= 100]
# Out:
#                          Clicks  Impressions   CTR  Position  CTR true visits  \
# Page
# https://miratrix.co.uk/     371       100673  0.37     42.59             0.17
#
#                                 Avg. Time on Page  Bounce Rate       Exit  \
# Page
# https://miratrix.co.uk/ 0 days 00:01:43.666666666    47.296667  54.286667
#
#                          Pageviews  Unique Pageviews  num_bounces
# Page
# https://miratrix.co.uk/       1396              1095          169

# %%
#Filter the data by pages that have recieved 100 or more clicks
filter1 = ga_gsc_data[(ga_gsc_data['Position'] <= 10) & (ga_gsc_data['Impressions'] >= 100)]

# %%
filter1
# Out:
#                                                     Clicks  Impressions   CTR  \
# Page
# https://miratrix.co.uk/author/nduddy/                   10          140  7.14
# https://miratrix.co.uk/miratrix-23-golden-squar...       3          227  1.32
# https://miratrix.co.uk/droidcon-not-just-for-devs/       1          166  0.60
#
#                                                     Position  CTR true visits  \
# Page
# https://miratrix.co.uk/author/nduddy/                   5.61             4.29
# https://miratrix.co.uk/miratrix-23-golden-squar...      7.59             0.00
# https://miratrix.co.uk/droidcon-not-just-for-devs/      8.00             0.00
#
#                                                    Avg. Time on Page  \
# Page
# https://miratrix.co.uk/author/nduddy/                0 days 00:02:52
# https://miratrix.co.uk/miratrix-23-golden-squar...   0 days 00:00:00
# https://miratrix.co.uk/droidcon-not-just-for-devs/   0 days 00:00:00
#
#                                                     Bounce Rate    Exit  \
# Page
# https://miratrix.co.uk/author/nduddy/                 22.223333   38.89
# https://miratrix.co.uk/miratrix-23-golden-squar...     0.000000  100.00
# https://miratrix.co.uk/droidcon-not-just-for-devs/     0.000000  100.00
#
#                                                     Pageviews  \
# Page
# https://miratrix.co.uk/author/nduddy/                      15
# https://miratrix.co.uk/miratrix-23-golden-squar...          4
# https://miratrix.co.uk/droidcon-not-just-for-devs/          1
#
#                                                     Unique Pageviews  \
# Page
# https://miratrix.co.uk/author/nduddy/                             13
# https://miratrix.co.uk/miratrix-23-golden-squar...                 4
# https://miratrix.co.uk/droidcon-not-just-for-devs/                 1
#
#                                                     num_bounces
# Page
# https://miratrix.co.uk/author/nduddy/                         6
# https://miratrix.co.uk/miratrix-23-golden-squar...            0
# https://miratrix.co.uk/droidcon-not-just-for-devs/            0

# %%
#Filter and sort your data 
ga_gsc_data[ga_gsc_data['Impressions'] >= 1000].sort_values(by="CTR true visits",
                                                            ascending=False)
# Out:
#                                                     Clicks  Impressions   CTR  \
# Page
# https://miratrix.co.uk/                                371       100673  0.37
# https://miratrix.co.uk/app-marketing-agency/            80        30824  0.26
# https://miratrix.co.uk/mobile-app-competitor-an...      16         1458  1.10
# https://miratrix.co.uk/app-store-optimization-s...       5         4177  0.12
# https://miratrix.co.uk/seo-agency-london/                0         1496  0.00
#
#                                                     Position  CTR true visits  \
# Page
# https://miratrix.co.uk/                                42.59             0.17
# https://miratrix.co.uk/app-marketing-agency/           26.84             0.10
# https://miratrix.co.uk/mobile-app-competitor-an...     30.64             0.07
# https://miratrix.co.uk/app-store-optimization-s...     70.02             0.02
# https://miratrix.co.uk/seo-agency-london/             215.61             0.00
#
#                                                            Avg. Time on Page  \
# Page
# https://miratrix.co.uk/                            0 days 00:01:43.666666666
# https://miratrix.co.uk/app-marketing-agency/       0 days 00:01:45.333333333
# https://miratrix.co.uk/mobile-app-competitor-an...           0 days 00:04:06
# https://miratrix.co.uk/app-store-optimization-s... 0 days 00:01:31.666666666
# https://miratrix.co.uk/seo-agency-london/             0 days 00:00:32.500000
#
#                                                     Bounce Rate       Exit  \
# Page
# https://miratrix.co.uk/                               47.296667  54.286667
# https://miratrix.co.uk/app-marketing-agency/          64.436667  60.913333
# https://miratrix.co.uk/mobile-app-competitor-an...    53.335000  89.475000
# https://miratrix.co.uk/app-store-optimization-s...    61.906667  60.256667
# https://miratrix.co.uk/seo-agency-london/            100.000000  66.665000
#
#                                                     Pageviews  \
# Page
# https://miratrix.co.uk/                                  1396
# https://miratrix.co.uk/app-marketing-agency/              210
# https://miratrix.co.uk/mobile-app-competitor-an...         30
# https://miratrix.co.uk/app-store-optimization-s...        198
# https://miratrix.co.uk/seo-agency-london/                   4
#
#                                                     Unique Pageviews  \
# Page
# https://miratrix.co.uk/                                         1095
# https://miratrix.co.uk/app-marketing-agency/                     181
# https://miratrix.co.uk/mobile-app-competitor-an...                26
# https://miratrix.co.uk/app-store-optimization-s...               160
# https://miratrix.co.uk/seo-agency-london/                          4
#
#                                                     num_bounces
# Page
# https://miratrix.co.uk/                                     169
# https://miratrix.co.uk/app-marketing-agency/                 31
# https://miratrix.co.uk/mobile-app-competitor-an...            1
# https://miratrix.co.uk/app-store-optimization-s...            1
# https://miratrix.co.uk/seo-agency-london/                     0

# %%
ga_page_traffic_data.head()
# Out:
#             Pageviews
# Day Index
# 2018-08-31       14.0
# 2018-09-01        6.0
# 2018-09-02       17.0
# 2018-09-03       14.0
# 2018-09-04       11.0

# %%
ga_page_traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2018-08-31 to 2019-08-31
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pageviews  366 non-null    float64
# dtypes: float64(1)
# memory usage: 5.7 KB

# %% [markdown]
# # create a altert loop

# %%
#Create a variable called num and assign it a integer 
num = -1

# %%
#Write an if statement that prints if the number is up, down or no change
if num > 0:
    print("It's UP!")
    
elif num == 0:
    print("No Change")
else:
    print("It's DOWN!")
# Out:
# It's DOWN!

# %% [markdown]
# ## Filter by date range and get the difference

# %%
start = '2018-08-31'
end = '2018-09-30'

# %%
#Create a mask that will select two dates. A mask will return a boolean (True/False) array 
mask = ((ga_page_traffic_data.index == start) | (ga_page_traffic_data.index == end))
mask[:30]
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
#Apply the mask to the dataframe
ga_page_traffic_data[mask]
# Out:
#             Pageviews
# Day Index
# 2018-08-31       14.0
# 2018-09-30        2.0

# %%
#Now we want to calculate the difference between the two rows and select the number
diff = ga_page_traffic_data[mask].diff().max()[0]

# %%
diff
# Out:
# -12.0

# %% [markdown]
# ## Create an altert

# %%
ga_page_traffic_data[mask].diff().max()[0]
# Out:
# -12.0

# %%
start = '2018-08-31'
end = '2018-09-30'

def alerts(df, start, end):
    mask = ((df.index == start) | (df.index == end)) #Create a mask
    diff = df[mask].diff().max()[0] #select the difference between the two dates
    chart = df[mask] #create a df with the mask applied
    if diff > 0:
        print("Traffic is up by {}".format(diff)) #print if traffic is above 0
    
    elif diff == 0:
        print("No Change") #print if traffic is unchanged
        
    else:
        print("Traffic is down by {}".format(diff))  #print if traffic is below 0
        
        #Print a bar chart to show the troublesome data
        fig = plt.figure(figsize=(15,5))

        ax = fig.add_subplot(111)

        figsize = (15,8)

        chart.plot(kind='bar',
                  figsize=figsize,
                  linewidth=0.5,
                  ax=ax
                 )

        #Global Plot settings
        plt.title('{} - {} : Traffic Drop in {}'.format(start,
                                                        end,
                                                        df.columns.values)) # set chart name

        #display the charts
        plt.show()

# %%
#Run the function
alerts(ga_page_traffic_data, start, end)
# Out:
# Traffic is down by -12.0
