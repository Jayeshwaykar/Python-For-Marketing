# %% [markdown]
# ## Libraries Needed

# %%
import pandas as pd
from pytrends.request import TrendReq
# %matplotlib inline

# %% [markdown]
# ## Importing and Basic Visualization

# %%
ga_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_keyword.csv')

# %%
ga_data
# Out:
#      # ---------------------------------------- Unnamed: 1 Unnamed: 2  \
# 0                                    # Miratrix        NaN        NaN
# 1                                    # Channels        NaN        NaN
# 2                           # 20180831-20190831        NaN        NaN
# 3    # ----------------------------------------        NaN        NaN
# 4                                           NaN        NaN        NaN
# ..                                          ...        ...        ...
# 376                                     8/28/19          3        NaN
# 377                                     8/29/19          0        NaN
# 378                                     8/30/19          1        NaN
# 379                                     8/31/19          4        NaN
# 380                                         NaN        691        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
ga_data.head(10)
# Out:
#    # ---------------------------------------- Unnamed: 1 Unnamed: 2  \
# 0                                  # Miratrix        NaN        NaN
# 1                                  # Channels        NaN        NaN
# 2                         # 20180831-20190831        NaN        NaN
# 3  # ----------------------------------------        NaN        NaN
# 4                                         NaN        NaN        NaN
# 5                                     Keyword      Users  New Users
# 6                              (not provided)        615        591
# 7                                      amazon          3          3
# 8                                   (not set)          1          1
# 9                                    miratrix          1          1
#
#   Unnamed: 3   Unnamed: 4       Unnamed: 5             Unnamed: 6  \
# 0        NaN          NaN              NaN                    NaN
# 1        NaN          NaN              NaN                    NaN
# ...

# %%
ga_data.tail(10)
# Out:
#     # ---------------------------------------- Unnamed: 1 Unnamed: 2  \
# 371                                    8/23/19          0        NaN
# 372                                    8/24/19          1        NaN
# 373                                    8/25/19          2        NaN
# 374                                    8/26/19          2        NaN
# 375                                    8/27/19          4        NaN
# 376                                    8/28/19          3        NaN
# 377                                    8/29/19          0        NaN
# 378                                    8/30/19          1        NaN
# 379                                    8/31/19          4        NaN
# 380                                        NaN        691        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 371        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
ga_kw_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_keyword.csv',skiprows=6,nrows=5)
ga_kw_traffic_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_keyword.csv',skiprows=14,nrows=366,parse_dates=['Day Index'])

# %%
ga_kw_data.head()
# Out:
#            Keyword  Users  New Users  Sessions Bounce Rate  Pages / Session  \
# 0   (not provided)    615        591       727      35.90%             1.75
# 1           amazon      3          3         3     100.00%             1.00
# 2        (not set)      1          1         1     100.00%             1.00
# 3         miratrix      1          1         1       0.00%             2.00
# 4  miratrix london      1          1         1       0.00%             1.00
#
#   Avg. Session Duration Contact From Good Lead (Goal 1 Conversion Rate)  \
# 0              00:01:42                                           0.00%
# 1              00:00:00                                           0.00%
# 2              00:00:00                                           0.00%
# 3              00:11:37                                           0.00%
# 4              00:05:27                                           0.00%
#
#    Contact From Good Lead (Goal 1 Completions)  \
# ...

# %%
ga_kw_traffic_data.head()
# Out:
#    Day Index  Users  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0 2018-08-31      5         NaN         NaN         NaN         NaN
# 1 2018-09-01      4         NaN         NaN         NaN         NaN
# 2 2018-09-02      5         NaN         NaN         NaN         NaN
# 3 2018-09-03      3         NaN         NaN         NaN         NaN
# 4 2018-09-04      4         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
ga_page_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_pages.csv',skiprows=6, nrows=376)
ga_page_traffic_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_pages.csv',skiprows=386, nrows=367,
                                  parse_dates = ['Day Index'])

# %%
ga_page_data.head()
# Out:
#                                 Page  Pageviews  Unique Pageviews  \
# 0                                  /        813               665
# 1                /www.miratrix.co.uk        515               388
# 2                     /get-in-touch/        336               163
# 3             /app-marketing-agency/        140               120
# 4  /app-store-optimization-services/        136               105
#
#   Avg. Time on Page  Entrances Bounce Rate  % Exit Page Value
# 0          00:02:05        641      14.35%  55.97%      £0.00
# 1          00:02:17        373      59.25%  56.89%      £0.00
# 2          00:01:06         23      10.53%  33.04%      £0.00
# 3          00:02:04         73      18.31%  57.86%      £0.00
# 4          00:01:30         22      14.29%  47.79%      £0.00

# %%
ga_page_traffic_data.head()
# Out:
#    Day Index  Pageviews  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0 2018-08-31         14         NaN         NaN         NaN         NaN
# 1 2018-09-01          6         NaN         NaN         NaN         NaN
# 2 2018-09-02         17         NaN         NaN         NaN         NaN
# 3 2018-09-03         14         NaN         NaN         NaN         NaN
# 4 2018-09-04         11         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
ga_ref_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_refering_sites.csv',skiprows=6, nrows=10)
ga_ref_traffic_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_refering_sites.csv',skiprows=18, 
                                   nrows=366,parse_dates = ['Day Index'])

# %%
ga_ref_data.head()
# Out:
#                      Source  Users  New Users  Sessions Bounce Rate  \
# 0           brightonseo.com     25         25        31       0.00%
# 1                 clutch.co     24         23        31      54.84%
# 2                  yell.com      5          5         7       0.00%
# 3  free-website-traffic.com      4          4         4      25.00%
# 4             growthbug.com      4          4         6       0.00%
#
#    Pages / Session Avg. Session Duration  \
# 0             1.42              00:01:08
# 1             1.58              00:01:04
# 2             1.86              00:00:24
# 3             2.25              00:00:36
# 4             1.17              00:05:15
#
#   Contact From Good Lead (Goal 1 Conversion Rate)  \
# 0                                           0.00%
# 1                                           0.00%
# 2                                           0.00%
# 3                                           0.00%
# ...

# %%
ga_ref_traffic_data.head()
# Out:
#    Day Index  Users
# 0 2018-08-31      0
# 1 2018-09-01      0
# 2 2018-09-02      0
# 3 2018-09-03      0
# 4 2018-09-04      1

# %%
ga_social_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_social_data.csv',skiprows=6, nrows=7)
ga_social_traffic_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_social_data.csv',skiprows=15, 
                                   nrows=366,parse_dates = ['Day Index'])

# %%
ga_social_data.head()
# Out:
#   Social Network  Users  New Users  Sessions Bounce Rate  Pages / Session  \
# 0       Facebook     29         29        29      37.93%             1.00
# 1        Twitter      6          4         7       0.00%             2.14
# 2         reddit      2          2         2     100.00%             1.00
# 3       LinkedIn      1          1         1     100.00%             1.00
# 4    LiveJournal      1          1         1       0.00%             1.00
#
#   Avg. Session Duration Contact From Good Lead (Goal 1 Conversion Rate)  \
# 0             <00:00:01                                           0.00%
# 1              00:04:50                                           0.00%
# 2              00:00:00                                           0.00%
# 3              00:00:00                                           0.00%
# 4              00:00:00                                           0.00%
#
#    Contact From Good Lead (Goal 1 Completions)  \
# ...

# %%
ga_social_traffic_data.head()
# Out:
#    Day Index  Users
# 0 2018-08-31      0
# 1 2018-09-01      0
# 2 2018-09-02      0
# 3 2018-09-03      0
# 4 2018-09-04      0

# %%
ga_other_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_other.csv',skiprows=6, nrows=5)
ga_other_traffic_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_other.csv',skiprows=13, 
                                   nrows=366,parse_dates = ['Day Index'])

# %%
ga_other_data.head()
# Out:
#                      Source  Users  New Users  Sessions Bounce Rate  \
# 0                 directory    116        110       143      18.18%
# 1           google_business     35         35        36      16.67%
# 2                       nav     26          0        43       6.98%
# 3              companyemail     16         12        23      43.48%
# 4  Clickky DevTools Listing      3          3         3       0.00%
#
#    Pages / Session Avg. Session Duration  \
# 0             2.14              00:02:34
# 1             1.81              00:02:00
# 2             2.40              00:04:04
# 3             1.65              00:00:59
# 4             2.67              00:01:45
#
#   Contact From Good Lead (Goal 1 Conversion Rate)  \
# 0                                           0.00%
# 1                                           0.00%
# 2                                           0.00%
# 3                                           0.00%
# ...

# %%
ga_other_traffic_data.head()
# Out:
#    Day Index  Users
# 0 2018-08-31      1
# 1 2018-09-01      0
# 2 2018-09-02      1
# 3 2018-09-03      1
# 4 2018-09-04      0

# %%
ga_total_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_total_channels.csv',skiprows=6, nrows=5)
ga_total_traffic_data =  pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\ga_data\ga_total_channels.csv',skiprows=13, 
                                   nrows=366,parse_dates = ['Day Index'])

# %%
ga_total_data.head()
# Out:
#   Channel Grouping  Users  New Users  Sessions Bounce Rate  Pages / Session  \
# 0   Organic Search    622        598       734      36.10%             1.75
# 1           Direct    601        599       665      57.74%             1.37
# 2          (Other)    194        160       248      18.15%             2.10
# 3         Referral    100         88       144      23.61%             3.85
# 4           Social     41         39        42      35.71%             1.19
#
#   Avg. Session Duration Contact From Good Lead (Goal 1 Conversion Rate)  \
# 0              00:01:43                                           0.00%
# 1              00:00:42                                           0.00%
# 2              00:02:35                                           0.00%
# 3              00:02:54                                           2.08%
# 4              00:00:49                                           0.00%
#
#    Contact From Good Lead (Goal 1 Completions)  \
# ...

# %%
ga_total_traffic_data.head()
# Out:
#    Day Index  Users
# 0 2018-08-31      5
# 1 2018-09-01      4
# 2 2018-09-02      5
# 3 2018-09-03      7
# 4 2018-09-04      7

# %% [markdown]
# ## Importing Google Search

# %%
#Importing query data from Google Search Console
qsc_query = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\gsc_data\gsc_query.csv')

# %%
qsc_query.head()
# Out:
#                             Query  Clicks  Impressions    CTR  Position
# 0                        miratrix      71          760  9.34%      6.23
# 1         app marketing agency uk      23          398  5.78%      3.36
# 2  mobile marketing agency london      11         2529  0.43%      3.97
# 3                app marketing uk       9          261  3.45%      2.01
# 4            app marketing agency       7         9860  0.07%     39.21

# %%
qsc_pages = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\gsc_data\gsc_pages.csv')

# %%
qsc_pages.head()
# Out:
#                                                 Page  Clicks  Impressions  \
# 0                            https://miratrix.co.uk/     371       100673
# 1       https://miratrix.co.uk/app-marketing-agency/      80        30824
# 2  https://miratrix.co.uk/mobile-app-competitor-a...      16         1458
# 3  https://miratrix.co.uk/blippar-the-message-isn...      11          517
# 4              https://miratrix.co.uk/author/nduddy/      10          140
#
#      CTR  Position
# 0  0.37%     42.59
# 1  0.26%     26.84
# 2   1.1%     30.64
# 3  2.13%     36.05
# 4  7.14%      5.61

# %%
qsc_country = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\gsc_data\gsc_country.csv')

# %%
qsc_country.head()
# Out:
#           Country  Clicks  Impressions    CTR  Position
# 0  United Kingdom     310        18836  1.65%     48.67
# 1           India      97        25622  0.38%     51.38
# 2   United States      29        14493   0.2%     45.92
# 3         Germany      14         2516  0.56%     55.01
# 4          France      12         2167  0.55%     43.88

# %%
qsc_device = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\gsc_data\gsc_device.csv')

# %%
qsc_device.head()
# Out:
#     Device  Clicks  Impressions    CTR  Position
# 0  Desktop     508       131897  0.39%     47.79
# 1   Mobile     105        31591  0.33%     36.65
# 2   Tablet       6          970  0.62%     39.56

# %%
qsc_apperance = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\gsc_data\gsc_apperance.csv')

# %%
qsc_apperance.head()
# Out:
#    Search Appearance  Clicks  Impressions CTR  Position
# 0  Web Light results       0           14  0%       7.5

# %% [markdown]
# ## Importing Adwords PPC

# %%
ppc_data = pd.read_csv('D:\Python for Marketing\Ex_Files_Python_Marketing\Ex_Files_Python_Marketing\Exercise Files\data\other_data\ppc_data.csv')

# %%
ppc_data.head()
# Out:
#    Unnamed: 0         Day              Ad group  Avg. CPC        CTR  \
# 0           0  2018-08-31  miratrix_ppc_adgroup  2.490563  16.894144
# 1           1  2018-09-01  miratrix_ppc_adgroup  2.472161   5.976134
# 2           2  2018-09-02  miratrix_ppc_adgroup  2.508561   6.824919
# 3           3  2018-09-03  miratrix_ppc_adgroup  2.548919   8.058366
# 4           4  2018-09-04  miratrix_ppc_adgroup  2.414868   6.884937
#
#        Campaign  Clicks  Conv. rate  Conversions         Cost  Cost / conv.  \
# 0  miratrix_ppc      75    0.225225            1  1105.809783   1105.809783
# 1  miratrix_ppc      17    1.193317            5  1035.835572    207.167114
# 2  miratrix_ppc       3    0.107411            1  2335.470042   2335.470042
# 3  miratrix_ppc      99    2.723735            7   655.072102     93.581729
# 4  miratrix_ppc      93    1.464435            7  1154.306794    164.900971
#
#   Final URL  Impr.  Keyword Keyword status  Max. CPC Mobile final URL  Status
# ...

# %% [markdown]
# ## Importing Facebook Ad csv

# %%
fd_data = pd.read_csv('D:\\Python for Marketing\\Ex_Files_Python_Marketing\\Ex_Files_Python_Marketing\\Exercise Files\\data\\other_data\\facebook_data_ads.csv')

# %%
fd_data.head()
# Out:
#    Unnamed: 0 Reporting starts Reporting ends Campaign name  Delivery  \
# 0           0       2014-02-21     2018-01-29     Campaign1         0
# 1           1       2015-12-04     2015-12-04     Campaign2  inactive
# 2           2       2015-10-21     2015-10-21     Campaign3  inactive
# 3           3       2015-10-20     2015-10-20     Campaign3  inactive
# 4           4       2015-10-20     2015-10-20     Campaign4  inactive
#
#    Mobile app installs  Mobile app actions  Cost per mobile app install (GBP)  \
# 0              11451.0                 NaN                           1.275683
# 1                  NaN                 NaN                                NaN
# 2                  2.0                 NaN                           3.530000
# 3                  2.0                 NaN                          16.500000
# 4                  NaN                 NaN                                NaN
#
#    Cost per mobile app action (GBP)  Desktop app installs  \
# ...

# %% [markdown]
# ## Importing Competitor site visability csv

# %%
# importing site vsiability csv
site_visibility = pd.read_csv('D:\\Python for Marketing\\Ex_Files_Python_Marketing\\Ex_Files_Python_Marketing\\Exercise Files\\data\\other_data\\site_visibility.csv')

# %%
site_visibility.head()
# Out:
#     Day Index  apptamin.com  miratrix.co.uk
# 0  2018-08-31     35.354169       79.576190
# 1  2018-09-01     97.529284       45.990192
# 2  2018-09-02      8.643297       63.922349
# 3  2018-09-03     19.927875       54.022379
# 4  2018-09-04     47.617416       57.075055

# %% [markdown]
# ## Import Keyword rank tracking data csv

# %%
ranking_data = pd.read_csv('D:\\Python for Marketing\\Ex_Files_Python_Marketing\\Ex_Files_Python_Marketing\\Exercise Files\\data\\other_data\\ranking_data.csv')

# %%
ranking_data.head()
# Out:
#     Day Index  app competitor analysis  app marketing agency  \
# 0  2018-08-31                        6                     1
# 1  2018-09-01                       21                     5
# 2  2018-09-02                       22                     7
# 3  2018-09-03                       28                    28
# 4  2018-09-04                       14                    14
#
#    app marketing agency london  app marketing agency uk  app marketing uk  \
# 0                            6                       10                21
# 1                           12                        8                 1
# 2                           14                       29                19
# 3                           29                       23                 0
# 4                           26                       17                11
#
#    app store optimisation agency  aso audit  mobile advertising agency  \
# 0                             20         17                         26
# ...

# %%
ranking_data[['Day Index','app competitor analysis']].head()
# Out:
#     Day Index  app competitor analysis
# 0  2018-08-31                        6
# 1  2018-09-01                       21
# 2  2018-09-02                       22
# 3  2018-09-03                       28
# 4  2018-09-04                       14

# %% [markdown]
# ## How to import google trends data via an API

# %%
pytrends = TrendReq(hl = 'en-GB',
                   tz= 360, #timezone
                   timeout=(10,25), #time out after seconts
                   retries=2, #retries 2 times
                   backoff_factor = 0.1) # stops after a few attempts

# %%
kw_list = ["seo audit", "aso audit","app marketing agency","seo agency","aso agency"]

# %% [markdown]
# ## Basic Visualization in pandas

# %%
# pass your variables over to google trends
pytrends.build_payload(kw_list, #keywords to lookup
                      cat = 83, #category to look in
                      timeframe= 'today 5-y', #timeframe
                      geo='', #country
                      gprop='')# region

# %%
trends_data = pytrends.interest_over_time()

# %%
trends_data.head()
# Out:
#             seo audit  aso audit  app marketing agency  seo agency  \
# date
# 2018-09-23          0          0                     0           0
# 2018-09-30          0          0                     0           0
# 2018-10-07          0          0                     0           0
# 2018-10-14          0          0                     0           0
# 2018-10-21          0          0                     0           0
#
#             aso agency  isPartial
# date
# 2018-09-23           0      False
# 2018-09-30           0      False
# 2018-10-07           0      False
# 2018-10-14           0      False
# 2018-10-21           0      False

# %%
trends_data.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Basic Visualisation in pandas

# %%
# Visualisation Google Analytics Data
ga_page_data[:10].sort_values(by='Pageviews', ascending=False).plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualisting Google Search Console data

# %%
# plot another bar chart, give in a secondary Y axis as impressions and stack the bar chart
qsc_query[:10].plot.bar(figsize=(25,5),secondary_y='Impressions',stacked=True)
# Out:
# <AxesSubplot:>

# %%
qsc_country[['Country','Clicks']][:10].plot.bar(figsize=(15,4),fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualising Adwords PPC data

# %%
ppc_data['Cost'][:10].plot(kind='line',figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualising Adwords PPC ata

# %%
fd_data.head()
# Out:
#    Unnamed: 0 Reporting starts Reporting ends Campaign name  Delivery  \
# 0           0       2014-02-21     2018-01-29     Campaign1         0
# 1           1       2015-12-04     2015-12-04     Campaign2  inactive
# 2           2       2015-10-21     2015-10-21     Campaign3  inactive
# 3           3       2015-10-20     2015-10-20     Campaign3  inactive
# 4           4       2015-10-20     2015-10-20     Campaign4  inactive
#
#    Mobile app installs  Mobile app actions  Cost per mobile app install (GBP)  \
# 0              11451.0                 NaN                           1.275683
# 1                  NaN                 NaN                                NaN
# 2                  2.0                 NaN                           3.530000
# 3                  2.0                 NaN                          16.500000
# 4                  NaN                 NaN                                NaN
#
#    Cost per mobile app action (GBP)  Desktop app installs  \
# ...

# %%
fd_data.plot.scatter(x='Mobile app installs',
                    y='Cost per mobile app install (GBP)',figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Mobile app installs', ylabel='Cost per mobile app install (GBP)'>

# %%
# plot two scatter graphs on top of each other and format it
ax = fd_data.plot.scatter(x='Post reactions',y='Cost per mobile app install (GBP)',
                         color = 'Magenta', label = 'Group 1',
                         alpha = .6, s=fd_data['Cost per mobile app install (GBP)']*5,
                         figsize = (15,5))
fd_data.plot.scatter(x='Mobile app installs', y='Cost per mobile app install (GBP)',
                    color='Cyan',
                    label = 'Group 2', ax=ax, alpha=.5,
                    figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Mobile app installs', ylabel='Cost per mobile app install (GBP)'>

# %% [markdown]
# ## Visualising Google Trend data

# %%
# Plot line graph with a secondary y of the largest value
trends_data.plot(secondary_y=('seo_agency'),figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Now plot a chart of the cummulative sum of all the data
trends_data.cumsum().plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='date'>
